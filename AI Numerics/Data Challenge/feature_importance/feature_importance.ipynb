# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Alle .pkl-Dateien im aktuellen Arbeitsverzeichnis finden
pkl_files = [f for f in os.listdir() if f.endswith(".pkl")]

# %%
df_list = []
for file in pkl_files:
    df = pd.read_pickle(file)

    # Dateiname ohne Pfad und Endung als Modellname
    modellname = os.path.splitext(os.path.basename(file))[0]

    # Neue Spalte anhängen
    df["Modell"] = modellname

    # Optional: Speichern im Dictionary (falls du willst)
    data_dict[modellname] = df

    # In Liste aufnehmen
    df_list.append(df)

# Alle zusammenfügen, falls du einen großen DataFrame willst
df_all = pd.concat(df_list, ignore_index=True)

# %%
df_all
# Out:
#                      Feature  average decrease in AUC     Modell
# 0                        age             4.999635e-02         GD
# 1                    anaemia            -4.093567e-03         GD
# 2   creatinine_phosphokinase            -2.306652e-02         GD
# 3                   diabetes             1.140351e-03         GD
# 4          ejection_fraction             1.286221e-01         GD
# 5        high_blood_pressure             0.000000e+00         GD
# 6                  platelets            -8.112208e-03         GD
# 7           serum_creatinine             4.585892e-02         GD
# 8               serum_sodium            -1.344298e-02         GD
# 9                        sex            -1.330409e-03         GD
# 10                   smoking            -5.847953e-04         GD
# 11                       age            -3.581871e-04  LinearSVM
# 12                   anaemia             1.743421e-03  LinearSVM
# 13  creatinine_phosphokinase            -5.851608e-03  LinearSVM
# 14                  diabetes            -6.542398e-04  LinearSVM
# 15         ejection_fraction             2.756579e-02  LinearSVM
# 16       high_blood_pressure            -7.196637e-03  LinearSVM
# 17                 platelets            -5.800439e-03  LinearSVM
# 18          serum_creatinine             7.915570e-02  LinearSVM
# 19              serum_sodium             2.010234e-03  LinearSVM
# 20                       sex            -5.555556e-04  LinearSVM
# 21                   smoking            -9.338450e-03  LinearSVM
# 22                       age             3.415205e-02       LRl2
# 23                   anaemia            -2.357456e-03       LRl2
# 24  creatinine_phosphokinase             1.169591e-04       LRl2
# 25                  diabetes            -2.876462e-03       LRl2
# 26         ejection_fraction             3.177632e-02       LRl2
# 27       high_blood_pressure             5.040205e-03       LRl2
# 28                 platelets            -1.129386e-03       LRl2
# 29          serum_creatinine             7.263158e-02       LRl2
# 30              serum_sodium             7.437865e-03       LRl2
# 31                       sex            -2.923977e-05       LRl2
# 32                   smoking            -1.110223e-17       LRl2
# 33                       age             3.845029e-02         RF
# 34                   anaemia             6.237208e-03         RF
# 35  creatinine_phosphokinase             2.616959e-03         RF
# 36                  diabetes             1.765351e-03         RF
# 37         ejection_fraction             9.416118e-02         RF
# 38       high_blood_pressure            -5.736477e-03         RF
# 39                 platelets             8.806652e-03         RF
# 40          serum_creatinine             9.147113e-02         RF
# 41              serum_sodium             4.543129e-03         RF
# 42                       sex             9.139254e-03         RF
# 43                   smoking            -4.256213e-03         RF

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
sns.barplot(
    data=df_all,
    x="Feature",
    y="average decrease in AUC",
    hue="Modell"
)

plt.title("Feature Importance – average decrease in AUC")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
