# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Alle .pkl-Dateien im aktuellen Arbeitsverzeichnis finden
pkl_files = [f for f in os.listdir() if f.endswith(".pkl")]

# %%
df_list = []
for file in pkl_files:
    df = pd.read_pickle(file)

    # Dateiname ohne Pfad und Endung als Modellname
    modellname = os.path.splitext(os.path.basename(file))[0]

    # Neue Spalte anhängen
    df["Modell"] = modellname

    # In Liste aufnehmen
    df_list.append(df)

# Alle zusammenfügen, falls du einen großen DataFrame willst
df_all = pd.concat(df_list, ignore_index=True)

# %%
df_all
# Out:
#                      Feature  average decrease in AUC     Modell
# 0                        age                 0.060614         GB
# 1                    anaemia                 0.000000         GB
# 2   creatinine_phosphokinase                -0.002529         GB
# 3                   diabetes                 0.000000         GB
# 4          ejection_fraction                 0.150362         GB
# 5        high_blood_pressure                -0.000897         GB
# 6                  platelets                -0.016447         GB
# 7           serum_creatinine                 0.099688         GB
# 8               serum_sodium                 0.000276         GB
# 9                        sex                -0.001875         GB
# 10                   smoking                -0.000556         GB
# 11                       age                -0.003015  LinearSVM
# 12                   anaemia                 0.001912  LinearSVM
# 13  creatinine_phosphokinase                -0.000596  LinearSVM
# 14                  diabetes                -0.006583  LinearSVM
# 15         ejection_fraction                 0.078015  LinearSVM
# 16       high_blood_pressure                -0.003476  LinearSVM
# 17                 platelets                -0.001835  LinearSVM
# 18          serum_creatinine                 0.053063  LinearSVM
# 19              serum_sodium                -0.010833  LinearSVM
# 20                       sex                -0.006436  LinearSVM
# 21                   smoking                -0.009576  LinearSVM
# 22                       age                 0.028757       LRl2
# 23                   anaemia                 0.000771       LRl2
# 24  creatinine_phosphokinase                 0.005673       LRl2
# 25                  diabetes                -0.002778       LRl2
# 26         ejection_fraction                 0.064178       LRl2
# 27       high_blood_pressure                 0.002262       LRl2
# 28                 platelets                 0.000011       LRl2
# 29          serum_creatinine                 0.069137       LRl2
# 30              serum_sodium                 0.015007       LRl2
# 31                       sex                 0.001111       LRl2
# 32                   smoking                -0.001667       LRl2
# 33                       age                 0.037235         RF
# 34                   anaemia                 0.010457         RF
# 35  creatinine_phosphokinase                 0.014709         RF
# 36                  diabetes                -0.004366         RF
# 37         ejection_fraction                 0.128458         RF
# 38       high_blood_pressure                 0.000227         RF
# 39                 platelets                -0.019426         RF
# 40          serum_creatinine                 0.081912         RF
# 41              serum_sodium                 0.007425         RF
# 42                       sex                 0.005689         RF
# 43                   smoking                 0.002082         RF

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
sns.barplot(
    data=df_all,
    x="Feature",
    y="average decrease in AUC",
    hue="Modell"
)

plt.title("Feature Importance – average decrease in AUC")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
